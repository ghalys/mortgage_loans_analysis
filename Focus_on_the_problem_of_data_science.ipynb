# %% [markdown]
# # **Les inégalités dans l’accès aux crédits immobiliers au Texas**
#
# ## Introduction
# Aux États-Unis, l'accès au crédit immobilier est essentiel pour permettre aux habitants de devenir propriétaires. Les institutions financières se basent sur divers critères pour évaluer les demandes de prêts, tels que le revenu ou l'endettement, mais des problèmes persistent, avec des demandes méritantes parfois refusées et d'autres acceptées à tort. Ces décisions peuvent refléter des biais socio-économiques, influencés par des facteurs comme la race, l'ethnicité ou la localisation.
#
# Aux États-Unis, la quasi-totalité des prêts immobiliers sont des prêts hypothécaires (~ 40% en France).
#
# Comment: une introduction doit "introduire" un document en présentant la suite, ce qui va être fait. Vous ne le faites pas ici
#
# ## **Quelques chiffres clés**
# - **Taux d’intérêt par rapport aux emprunteurs blancs :**
#   - 28% des blancs
#   - 26% des Hispaniques avec une hausse de 9 points
#   - Moyenne des taux : 4,9% pour les Hispaniques, 4,8% pour les blancs, 6,4% pour les Afro-Américains
#
# - **Les emprunteurs asiatiques issus de minorités étaient 7,7 points de pourcentage supérieurs par rapport aux emprunteurs blancs.**
#
# => cette dernière phrase est incompréhensible
#
# *Source : HMDA*
#
# ## **Quelques données sur les prêts hypothécaires américains**
# - L'emprunteur moyen rembourse son crédit en 23 ans.
# - En réponse au COVID-19, le taux hypothécaire a évolué passant de **3,5%** début 2020 à **2,98%** pendant la pandémie, puis a augmenté en 2023 jusqu’à **7%** afin de contrer l'inflation post-pandémie.
# - En 2022, environ **74 %** des acheteurs ont financé l'achat de leur maison avec un prêt hypothécaire.
#
#
# ## **Le processus d’octroi des prêts hypothécaires**
# ![Le processus d’octroi des prêts hypothécaires](Visualisations/processus_octroi_credit.png)
#
# ## **Question**
# Y’a-t-il des biais discriminatoires dans le processus d'octroi des crédits bancaires dans l'État du Texas ? Et si oui, lesquels ?
#
# ## **Pourquoi le Texas ?**
#
# - **Population Diversifiée** : 29 millions d'habitants : blancs (42,5%), hispaniques (39,7%), et afro-américains (11,8%).
# - **Taux de refus élevés** : Taux de refus supérieurs à la moyenne nationale.
#
# => chiffres, et d'où sont-ils issus
#
# - **Contexte Politique** : L'orientation conservatrice de l'État peut impacter les politiques de crédit.
#
# ## **La cible de notre étude**
#
# ### 1) Les institutions financières :
# Notre solution vise d'abord les institutions financières, et plus particulièrement leurs employés qui peuvent prendre des décisions erronées. En effet, durant le processus d’octroi du crédit, il y a un contact direct entre les employés et les clients demandeurs, ce qui peut conduire à des biais discriminatoires.
#
# Ces biais peuvent conduire à des décisions d'octroi de prêt qui ne reflètent pas la capacité réelle de remboursement des emprunteurs. Par exemple, des critères biaisés sur des aspects démographiques, raciaux ou socio-économiques peuvent exclure des emprunteurs qualifiés, créant une discrimination injuste.
#
# - **Perte de clients :** Si les institutions financières discriminent involontairement ou délibérément certains groupes de clients, elles risquent de perdre ces clients potentiels qui pourraient se tourner vers d'autres prestataires plus équitables. Cela peut aussi ternir leur réputation, surtout si les pratiques discriminatoires deviennent publiques.
#
# - **Conséquences internes :** Au sein des institutions, les biais inconscients ou volontaires des employés peuvent entraîner des pratiques discriminatoires. Ces pratiques peuvent se produire lors des interactions humaines, comme lors des discussions sur les conditions des prêts. Les employés peuvent être influencés par des stéréotypes, que ce soit en raison de leur propre jugement ou d'algorithmes imparfaits utilisés pour évaluer la solvabilité des emprunteurs.
#
# ### 2) Les agences de protection du consommateur:
# Notre solution vise également à servir de base d’évaluation pour les agences de protection du consommateur, comme le Department of Housing and Urban Development (HUD). Il s’agit d’une agence fédérale des États-Unis, créée pour promouvoir un accès équitable au logement et lutter contre la discrimination dans ce secteur. Sa mission principale est de s'assurer que tous les citoyens, indépendamment de leur race, de leur sexe, de leur religion ou de leur situation économique, puissent bénéficier de logements décents et abordables. Le HUD travaille également à renforcer les communautés, à favoriser l'accès à la propriété, et à fournir des aides financières aux ménages à faibles revenus. L'agence est notamment responsable de l'application des lois contre la discrimination dans le secteur du logement, en veillant à ce que personne ne soit injustement exclu de l'accès à un logement.

# %% [markdown]
# ## **HMDA : Une source de données riche**
# Le Home Mortgage Disclosure Act (HMDA) est une loi fédérale des États-Unis qui oblige depuis 1975 certaines institutions financières à fournir des données hypothécaires au public. La base de données publiée sur le site [https://ffiec.cfpb.gov/data-browser/data/](https://ffiec.cfpb.gov/data-browser/data/). Elle contient des données publiques sur les prêts hypothécaires pour chaque État des États-Unis, collectées annuellement par le Bureau de Protection Financière des Consommateurs (CFPB) entre 2018 et 2023. On a environ 900 000 instances par an et 99 variables.

# %% [markdown]
# # **Les premières explorations du dataset**

# %% [markdown]
# ## **1-Explication de variables**

# %% [markdown]
# Ci-dessous un tableau récapitulatif des variables de notre dataset de crédit hypothécaire avec leurs explications et leur importance subjective pour la prédiction de la décision de prêt et l’identification des biais discriminatoires.
#
# | **Variable**                            | **Description**                                                                                                                                                                                                                                                   | **Importance subjective dans la prédiction**                   | **Importance subjective dans l’analyse des biais**         |
# |-----------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------|---------------------------------------------------------|
# | **activity_year**                       | Année de l’activité enregistrée, représente l'année de la demande de prêt.                                                                                                                                                                                       | Moyenne – peut indiquer des tendances temporelles.  | Faible – peu de relation directe avec les biais.        |
# | **derived_msa-md**                      | Zone métropolitaine (MSA) ou division métropolitaine.                                                                                                                                                                      | Moyenne – peut influer sur les décisions régionales.| Élevée – pourrait refléter des disparités régionales.   |
# | **derived_loan_product_type**           | Type de prêt dérivé pour faciliter la catégorisation des dossiers (basé sur le type de prêt et le statut du privilège).                                                                                                    | Moyenne – utile pour la segmentation de prêt.       | Moyenne – influence potentielle sur le type de clients. |
# | **derived_dwelling_category**           | Catégorie de logement dérivée pour simplifier les requêtes (basée sur le type de construction et le nombre d'unités totales).                                                                                             | Moyenne – pour comprendre le type de logement.      | Faible – impact limité sur les biais.                   |
# | **derived_ethnicity**                   | Ethnicité dérivée de l'emprunteur.                                                                                                                                                                                         | Élevée – peut affecter les probabilités de prêt.    | Élevée – nécessaire pour identifier les biais ethniques. |
# | **derived_race**                        | Race dérivée de l'emprunteur.                                                                                                                                                                                              | Élevée – impact possible sur la décision de prêt.   | Élevée – essentiel pour identifier les biais raciaux.    |
# | **derived_sex**                         | Sexe dérivé de l'emprunteur.                                                                                                                                                                                               | Moyenne – possible facteur discriminatoire.         | Élevée – essentiel pour identifier les biais de genre.   |
# | **action_taken**                        | Décision prise concernant la demande de prêt (accordé, refusé, etc.).                                                                                                                                                      | Élevée – cible de la prédiction.                    | Moyenne – permet de vérifier si des biais influencent la décision. |
# | **purchaser_type**                      | Type d'acheteur (organisme ou institution achetant le prêt).                                                                                                                                                               | Faible – moins pertinent pour la prédiction.        | Faible – impact indirect sur les biais.                 |
# | **preapproval**                         | Demande pré-approuvée ou non.                                                                                                                                                                                              | Moyenne – reflète le sérieux de l'intention.        | Faible – importance limitée dans les biais.             |
# | **loan_type**                           | Type de prêt demandé.                                                                                                                                                                                                      | Moyenne – influence les conditions de prêt.         | Faible – impact limité sur les biais.                   |
# | **loan_purpose**                        | But du prêt (achat, refinancement, etc.).                                                                                                                                                                                  | Moyenne – aide à distinguer les types de demande.   | Faible – impact limité sur les biais.                   |
# | **lien_status**                         | Statut de la garantie (en lien avec le bien immobilier).                                                                                                                                                                   | Faible – importance technique dans la décision.     | Faible – impact indirect sur les biais.                 |
# | **reverse_mortgage**                    | Indique si le prêt est un prêt hypothécaire inversé (pour les seniors).                                                                                                                                                    | Moyenne – cible un public spécifique.               | Faible – impact limité pour les biais.                  |
# | **open-end_line_of_credit**             | Indique s'il s'agit d'une ligne de crédit renouvelable.                                                                                                                                                                    | Moyenne – affecte les conditions de crédit.         | Moyenne – peut refléter une tendance sur les demandes.   |
# | **business_or_commercial_purpose**      | Indique si le prêt est pour un but commercial.                                                                                                                                                                             | Moyenne – pour filtrer les prêts résidentiels.      | Faible – peu de lien avec les biais de la population.   |
# | **loan_amount**                         | Montant total du prêt demandé.                                                                                                                                                                                              | Élevée – influence le risque de crédit.             | Moyenne – dépend des conditions socio-économiques.      |
# | **loan_to_value_ratio**                 | Ratio entre le montant du prêt et la valeur du bien.                                                                                                                                                                       | Moyenne – indicateur de risque.                     | Faible – impact limité sur les biais.                   |
# | **interest_rate**                       | Taux d'intérêt appliqué au prêt.                                                                                                                                                                                           | Élevée – condition essentielle pour le remboursement.| Moyenne – potentiellement biaisée en fonction du profil.|
# | **rate_spread**                         | Écart de taux, différence avec les taux d’intérêt moyens.                                                                                                                                                                  | Moyenne – indicateur de conditions de prêt.         | Moyenne – possibilité de biais selon profil.            |
# | **hoepa_status**                        | Indique si le prêt est considéré comme un prêt à haut coût selon le HOEPA.                                                                                                                                                 | Moyenne – influence la perception de risque.        | Moyenne – pourrait révéler des pratiques discriminatoires.|
# | **total_loan_costs**                    | Coût total du prêt pour l'emprunteur.                                                                                                                                                                                      | Moyenne – détermine l’accessibilité.                | Moyenne – possible différence entre groupes sociaux.    |
# | **total_points_and_fees**               | Total des frais de dossier et points appliqués.                                                                                                                                                                            | Faible – influence limitée sur la décision finale.  | Faible – peu de relation directe avec les biais.        |
# | **origination_charges**                 | Total des frais d'origine payés par l'emprunteur à la clôture.                                                                                                                                                             | Faible – moins pertinent dans la décision de prêt.  | Faible – peu de lien avec les biais.                    |
# | **discount_points**                     | Points payés pour réduire le taux d’intérêt.                                                                                                                                                                               | Faible – importance limitée sur la décision.        | Faible – impact indirect sur les biais.                 |
# | **lender_credits**                      | Montant des crédits accordés par le prêteur (réduction des frais de clôture).                                                                                                                                              | Faible – généralement négligeable dans la décision. | Faible – peu d’impact sur les biais.                    |
# | **loan_term**                           | Durée du prêt en mois.                                                                                                                                                                                                     | Élevée – influence sur le montant total à rembourser.| Moyenne – pourrait varier selon les groupes d’âge.      |
# | **prepayment_penalty_term**             | Durée en mois d'une éventuelle pénalité de remboursement anticipé.                                                                                                                                                         | Faible – importance secondaire.                     | Faible – peu de lien avec les biais.                    |
# | **intro_rate_period**                   | Durée jusqu'à la première révision du taux d’intérêt après la clôture.                                                                                                                                                     | Faible – rarement influent pour la décision.        | Faible – impact indirect sur les biais.                 |
# | **negative_amortization**               | Indique si le prêt inclut des conditions qui augmentent le capital restant dû.                                                                                                                                             | Moyenne – peut influencer le risque.                | Moyenne – potentiellement biaisé si proposé à certains profils.|
# | **interest_only_payment**               | Indique si le prêt inclut des paiements uniquement d'intérêts.                                                                                                                                                             | Moyenne – impact sur la charge mensuelle.           | Faible – peu d’impact direct sur les biais.             |
# | **property_value**                      | Valeur du bien immobilier garantissant le prêt.                                                                                                                                                                            | Élevée – indicateur clé pour évaluer le prêt.       | Moyenne – reflète le marché local mais peu sur les biais. |
# | **occupancy_type**                      | Type d'occupation du bien (résidence principale, secondaire, etc.).                                                                                                                                                        | Moyenne – peut influencer le risque de crédit.      | Faible – impact limité sur les biais.                   |
# | **total_units**                         | Nombre d'unités de logement associées au bien immobilier.                                                                                                                                                                 | Moyenne – aide à évaluer le type de propriété.      | Faible – peu d’impact direct sur les biais.             |
# | **multifamily_affordable_units**        | Pourcentage d’unités abordables dans un bien multifamilial.                                                                                                                                                                | Moyenne – pertinence dans le type de prêt.          | Moyenne – lien indirect avec les biais socio-économiques.|
# | **income**                              | Revenu annuel brut de l'emprunteur utilisé pour la décision de crédit.                                                                                                                                                     | Élevée – facteur clé de la solvabilité.             | Moyenne – peut refléter des différences de revenu selon les groupes sociaux.|
# | **debt_to_income_ratio**                | Ratio entre la dette totale et le revenu total de l'emprunteur.                                                                                                                                                            | Élevée – facteur crucial de risque de crédit.       | Moyenne – peut indiquer une discrimination indirecte.    |
# | **applicant_age**                       | Âge de l’emprunteur.                                                                                                                                                                                                      | Moyenne – influence les conditions d’éligibilité.   | Élevée – possibilité de biais selon l’âge.              |
# | **submission_of_application**           | Soumission directe ou non de la demande de prêt.                                                                                                                                                                           | Faible – peu pertinent pour la décision finale.     | Faible – impact indirect sur les biais.                 |
# | **initially_payable_amount**            | Montant initialement payable au moment de la souscription.                                                                                                                                                                | Moyenne – affecte la charge de paiement initiale.   | Faible – impact indirect sur les biais.                 |
# | **population_density**                  | Densité de population dans la zone du bien hypothéqué.                                                                                                                                                                    | Moyenne – influe potentiellement sur les prix.      | Moyenne – pourrait révéler des disparités géographiques.|
# | **aus-1, aus-2, aus-3, aus-4, aus-5**    | Systèmes automatisés d'évaluation du crédit utilisés par l’institution financière pour évaluer la demande de prêt (par exemple : FICO, Experian).                                         | Moyenne – reflète les critères d’approbation utilisés.         | Élevée – potentiellement biaisé si certains AUS favorisent des profils spécifiques. |
# | **denial_reason-1, 2, 3, 4**                      | Raisons de refus basée sur le ratio dette-revenu.                                                                                                                                          | Élevée – crucial pour évaluer la capacité de remboursement.     | Moyenne – peut indiquer une discrimination financière indirecte.   |                                     |
# | **tract_population**                     | Population totale du secteur de recensement.                                                                                                                                              | Moyenne – reflète les conditions du marché local.               | Moyenne – pourrait révéler des tendances socio-économiques.                         |
# | **tract_minority_population_percent**    | Pourcentage de la population issue des minorités dans le secteur de recensement.                                                                                                          | Moyenne – facteur indirect.                                     | Élevée – clé pour évaluer les biais démographiques potentiels.                      |
# | **ffiec_msa_md_median_family_income**    | Revenu familial médian dans la région, selon la FFIEC (Federal Financial Institutions Examination Council).                                                                               | Moyenne – reflète le niveau socio-économique local.             | Moyenne – indicatif des disparités économiques.                                     |
# | **tract_to_msa_income_percentage**       | Ratio de revenu entre le secteur de recensement et le revenu médian de la région.                                                                                                        | Moyenne – reflète les écarts de richesse dans la région.        | Moyenne – possible indicateur de disparités de revenus.                             |
# | **tract_owner_occupied_units**           | Nombre d'unités résidentielles occupées par leur propriétaire dans le secteur.                                                                                                           | Moyenne – pertinent pour la valeur des biens dans le secteur.   | Moyenne – peut indiquer les préférences d’achat propres à un secteur.               |
# | **tract_one_to_four_family_homes**       | Nombre de résidences individuelles dans le secteur de recensement.                                                                                                                       | Moyenne – reflète la composition résidentielle.                 | Faible – impact limité pour l’analyse des biais.                                    |
# | **tract_median_age_of_housing_units**    | Âge médian des logements dans le secteur.                                                                                                                                                | Moyenne – peut influencer la valeur des biens.                  | Faible – peu de lien direct avec les biais.                                         |
#
# ### Synthèse :
#
# A ce 1er stade de l'exploration, nous avons identifié :
#
# **Des variables importantes pour la prédiction :**
# - `derived_ethnicity`, `derived_race`, `derived_sex`, `action_taken`, `loan_purpose`, `loan_amount`, `debt_to_income_ratio`, `interest_rate`, `loan_to_value_ratio`
# - **Rôle** : Ces variables capturent des caractéristiques socio-démographiques et financières essentielles qui influencent directement la décision de crédit. Par exemple, le taux d’intérêt et le ratio prêt-valeur (`loan_to_value_ratio`) permettent d’évaluer le risque de l’emprunt.
#
# **Des variables importantes pour identifier les biais discriminatoires :**
# - `derived_ethnicity`, `derived_race`, `derived_sex`, `derived_msa-md`, `tract_minority_population_percent`, `ffiec_msa_md_median_family_income`, `applicant_age`, `income`
# - **Rôle** : Ces variables sont cruciales pour détecter des inégalités potentielles basées sur l’origine ethnique, le sexe, la localisation, et le niveau de revenu. Le pourcentage de minorités dans le secteur (`tract_minority_population_percent`) et le revenu moyen des familles (`ffiec_msa_md_median_family_income`) permettent de contextualiser le profil socio-économique de chaque demande.
#
# On n'exclut pas la considération d'autres variables pour la suite de notre étude.
#
# => voir mon commentaire sur les variables explicatives. Il manque aussi la description de la, ou les variables expliquées

# %% [markdown]
# ### **2-Distribution des données**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
import scipy.stats as ss


filepath = 'small_dataset_20.csv'

# %% [markdown]
# On teste nos données sur un plus petit jeu de données pour une question de difficulté à gérer le traitement d'un grand volume de donnée (environ 4go). Voici le code qui nous a servi pour générer notre nouveau dataset.

# %%
# a=[]
# for i in range(2018, 2024):
#   df = pd.read_csv('original_data/state_TX_'+str(i)+'.csv')
#   sampled_df = df.sample(frac=0.20, random_state=42)
#   a.append(sampled_df)
# final_df=pd.concat(a)
# final_df.to_csv('small_dataset_20.csv')

# %%
df = pd.read_csv(filepath)
print(f' the shape of the dataset is : {df.shape}')
df.head()
# Out:
#  the shape of the dataset is : (1776131, 100)
#    Unnamed: 0  activity_year                   lei  derived_msa-md state_code  \
# 0       41369           2018  5493004RLLKTQS8K7U51           19124         TX
# 1     1066341           2018  OSTXQZDK5VDIPSIEIC53           23104         TX
# 2      410544           2018  549300CB67L6KPJLHE19           46340         TX
# 3      645957           2018  549300LYRWPSYPK6S325           23104         TX
# 4      535802           2018  549300GKFNPRWNS0GF29           12420         TX
#
#    county_code  census_tract conforming_loan_limit  \
# 0      48121.0  4.812102e+10                     C
# 1      48367.0  4.836714e+10                     C
# 2      48423.0  4.842300e+10                     C
# 3      48439.0  4.843911e+10                     C
# 4      48453.0  4.845300e+10                     C
#
#        derived_loan_product_type               derived_dwelling_category  ...  \
# ...

# %% [markdown]
# Pour une meilleure visibilité des différentes races, on renomme les différentes catégories

# %%
def rename_race_data(df):
    new_df = df.copy()
    new_df['derived_race'] = df['derived_race'].replace({
        'American Indian or Alaska Native' : "American Indian",
        'Black or African American': 'African American',
        '2 or more minority races' : "Others",
        'Native Hawaiian or Other Pacific Islander': 'Others',
        'Joint': 'Race Not Available',
        'Free Form Text Only': 'Race Not Available'
    })
    return new_df

df = rename_race_data(df)

# %%
# Calculate the distribution of race
race_counts = df.groupby('derived_race')["derived_race"].count()
# Calculate the distribution of races according to approved loans
approved_counts = df[df['action_taken'] == 1]['derived_race'].value_counts()

# %%
def create_pie_chart(race_counts, title):
    plt.figure(figsize=(8, 8))

    colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700', '#FF6347', '#8A2BE2']
    explode = [0.1] * len(race_counts)

    wedges, texts, autotexts = plt.pie(
        race_counts,
        labels=race_counts.index,
        autopct='%1.1f%%',
        startangle=90,
        explode=explode,
        colors=colors[:len(race_counts)],
        pctdistance=0.75,
        labeldistance=1.1
    )

    for text in autotexts:
        text.set_fontsize(14)
        text.set_color('black')
        text.set_weight('bold')

    plt.title(title)
    plt.axis('equal')
    plt.show()

create_pie_chart(race_counts, title=f'Distribution of mortgage applications by Races in Texas')

# %% [markdown]
# Ce graphique représente la distribution des données selon la race. Les demandeurs sont majoritairement blancs avec une part de 55% des données. Les asiatiques et les afro-américains ont des pourcentages équivalents (7.2% et 6.9% respectivement), tandis que les autres races comme les amérindiens et les haïtiens représentent une très petite minorité dans notre dataset (moins de 1%).
# Il est à noter que 29.7% des données qu’on possède ne mentionne aucune race, mais on estime qu’on a suffisamment de données (environ 6 millions de données).

# %%
def create_table_count(race_counts, coefficient):

    race_counts_df = race_counts.reset_index(name='Count')
    race_counts_df.columns = ['Race', 'Count']
    race_counts_df['Count'] = race_counts_df['Count'] * coefficient

    total_count = race_counts_df['Count'].sum()
    race_counts_df['Percentage'] = round((race_counts_df['Count'] / total_count) * 100,2)
    race_counts_df['Percentage'] = race_counts_df['Percentage'].astype(str) + '%'


    print(tabulate(race_counts_df, headers='keys', tablefmt='fancy_grid'))
    pass

create_table_count(race_counts, coefficient=5)
# Out:
# ╒════╤════════════════════╤═════════╤══════════════╕
# │    │ Race               │   Count │ Percentage   │
# ╞════╪════════════════════╪═════════╪══════════════╡
# │  0 │ African American   │  638215 │ 7.19%        │
# ├────┼────────────────────┼─────────┼──────────────┤
# │  1 │ American Indian    │   56540 │ 0.64%        │
# ├────┼────────────────────┼─────────┼──────────────┤
# │  2 │ Asian              │  610360 │ 6.87%        │
# ├────┼────────────────────┼─────────┼──────────────┤
# │  3 │ Others             │   31210 │ 0.35%        │
# ├────┼────────────────────┼─────────┼──────────────┤
# │  4 │ Race Not Available │ 2634065 │ 29.66%       │
# ├────┼────────────────────┼─────────┼──────────────┤
# │  5 │ White              │ 4910265 │ 55.29%       │
# ╘════╧════════════════════╧═════════╧══════════════╛

# %%
def create_bar_chart_loan_per_race(total_approved_counts, total_race_counts, title='between 2018 and 2023'):

  total_approved_counts = total_approved_counts.drop('Race Not Available')
  total_race_counts = total_race_counts.drop('Race Not Available')

  percentages = (total_approved_counts / total_race_counts) * 100

  plt.figure(figsize=(10, 6))
  colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2']
  percentages.sort_values().plot(kind='barh', color=colors)

  plt.xlabel('Percentage of loans originated (%)')
  plt.ylabel('Race')
  plt.title('For each race, percentage of loans originated')
  plt.xlim(0, 100)

  plt.show()
  pass

create_bar_chart_loan_per_race(approved_counts, race_counts)

# %% [markdown]
# On a exploré le pourcentage de prêts accordés pour chaque race. On remarque que les blancs et les asiatiques ont un pourcentage avoisinant les 60% de prêts acceptés, tandis que pour les afro-américains et autres minorités, ce pourcentage diminue à moins de 50% d’après les données qu’on possède. Cela peut être dû à des discriminations mais peut être aussi à des facteurs socio-économiques propres à la race, comme par exemple des minorités qui ont un accès plus difficile à l'emploi et donc une capacité moindre à prendre et garantir un prêt auprès de la banque. Ainsi, notre étude cherchera à comprendre les raisons de cette disparité.

# %% [markdown]
# ## Analyse des Taux de Prêts Accordés et de Demandes Refusées par Type de Prêt

# %%
def plot_loan_action_analysis(file_path):
    # Charger les données
    state_TX = pd.read_csv(file_path, low_memory=False)

    # Remapper les valeurs de 'action_taken'
    action_mapping = {1: 'Loan originated', 3: 'Application denied'}
    state_TX['action_taken_desc'] = state_TX['action_taken'].map(action_mapping)

    # Remapper les valeurs de 'loan_purpose'
    loan_purpose_mapping = {
        1: 'Home purchase', 2: 'Home improvement',
        3: 'Refinancing', 4: 'Other purpose'
    }
    state_TX['loan_purpose_desc'] = state_TX['loan_purpose'].map(loan_purpose_mapping)

    # Filtrer les données pour les actions pertinentes
    filtered_data = state_TX[state_TX['action_taken_desc'].isin(['Loan originated', 'Application denied'])]

    # Calculer le pourcentage par loan_purpose
    loan_purpose_percentage = filtered_data.groupby(['loan_purpose_desc', 'action_taken_desc']).size().unstack(fill_value=0)
    loan_purpose_percentage = loan_purpose_percentage.apply(lambda x: (x / x.sum()) * 100, axis=1)

    # Créer la figure et les axes
    fig, ax = plt.subplots(figsize=(10, 6))

    # Graphique pour loan_purpose
    loan_purpose_bars = ax.barh(
        loan_purpose_percentage.index,
        loan_purpose_percentage['Loan originated'],
        color='#4CAF50',
        edgecolor='black',
        linewidth=1.5,
        label='Loan originated'
    )

    # Ajouter les barres pour les demandes refusées
    ax.barh(
        loan_purpose_percentage.index,
        loan_purpose_percentage['Application denied'],
        left=loan_purpose_percentage['Loan originated'],
        color='#F44336',
        edgecolor='black',
        linewidth=1.5,
        label='Application denied'
    )

    # Configurer le graphique
    ax.set_title('Analyse des Taux de Prêts Accordés et de Demandes Refusées par Type de Prêt', fontsize=16)
    ax.set_xlabel('Pourcentage (%)', fontsize=12)
    ax.set_ylabel('Type de Prêt', fontsize=12)
    ax.legend(title='Action Taken')
    plt.xlim(0, 100)  # Limiter l'axe des x à 100%

    # Afficher le graphique
    sns.despine()
    plt.tight_layout()
    plt.show()

# %%
plot_loan_action_analysis(filepath)

# %% [markdown]
# Plus de 80 % des demandes de prêts pour l'achat de logements ont été acceptées, indiquant un risque perçu plus faible par les prêteurs. En revanche, environ 40% des demandes pour des prêts d'amélioration de l'habitat ont été acceptées, suggérant un risque plus élevé. Cela souligne l'importance du type de projet dans l'évaluation des demandes de crédit.

# %% [markdown]
# ## lien_status : une variable importante pour la prise de décision

# %%
def plot_lien_status_analysis(df):
  # Charger les données
  state_TX = df.copy()
  # Remapper les valeurs de 'action_taken'
  action_mapping = {1: 'Loan originated', 3: 'Application denied'}
  state_TX['action_taken_desc'] = state_TX['action_taken'].map(action_mapping)

  # Remapper les valeurs de 'lien_status'
  lien_status_mapping = {1: 'Secured by a first lien', 2: 'Secured by a subordinate lien'}
  state_TX['lien_status_desc'] = state_TX['lien_status'].map(lien_status_mapping)

  # Filtrer les données pour les actions pertinentes
  filtered_data = state_TX[state_TX['action_taken_desc'].isin(['Loan originated', 'Application denied'])]

  # Calculer le pourcentage par lien_status
  lien_status_percentage = filtered_data.groupby(['lien_status_desc', 'action_taken_desc']).size().unstack(fill_value=0)
  lien_status_percentage = lien_status_percentage.apply(lambda x: (x / x.sum()) * 100, axis=1)

  # Créer la figure et les axes
  fig, ax = plt.subplots(figsize=(8, 5))

  # Graphique pour lien_status
  lien_status_bars = ax.barh(
      lien_status_percentage.index,
      lien_status_percentage['Loan originated'],
      color='#87CEEB',
      edgecolor='black',
      linewidth=1.5,
      label='Loan originated'
  )

  # Ajouter les barres pour les demandes refusées
  ax.barh(
      lien_status_percentage.index,
      lien_status_percentage['Application denied'],
      left=lien_status_percentage['Loan originated'],
      color='#4682B4',
      edgecolor='black',
      linewidth=1.5,
      label='Application denied'
  )

  # Configurer le graphique
  ax.set_title('Analyse des Taux de Prêts Accordés et de Demandes Refusées par Statut de Lien', fontsize=16)
  ax.set_xlabel('Pourcentage (%)', fontsize=12)
  ax.set_ylabel('Statut de Lien', fontsize=12)
  ax.legend(title='Action Taken')
  plt.xlim(0, 100)  # Limiter l'axe des x à 100%

  # Afficher le graphique
  sns.despine()
  plt.tight_layout()
  plt.show()
  pass

# %%
plot_lien_status_analysis(df)

# %% [markdown]
# Le taux d'acceptation des crédits diffère significativement entre les prêts de premier lien et les prêts subordonnés. Les prêts de premier lien sont généralement considérés comme moins risqués pour les prêteurs, car ils ont la priorité sur les actifs en cas de défaut de paiement.

# %% [markdown]
# ## Existe-t-il des biais discriminatoires dans l'octroi de prêts en fonction du sexe ou de l'éthnicité ?

# %%
def rename_variables(df):
    """ map action_taken, derived_sex, and derived_ethnicity."""
    state_TX = df.copy()

    # Remapper les valeurs de 'action_taken'
    action_mapping = {
        1: 'Loan originated',
        2: 'Application approved but not accepted',
        3: 'Application denied',
        4: 'Application withdrawn by applicant',
        5: 'File closed for incompleteness',
        6: 'Purchased loan',
        7: 'Preapproval request denied',
        8: 'Preapproval request approved but not accepted'
    }
    state_TX['action_taken_desc'] = state_TX['action_taken'].map(action_mapping)

    # Remapper les valeurs de 'derived_sex'
    sex_mapping = {
        'Male': 'Male',
        'Female': 'Female',
        'Joint': 'Not Available',
        'Sex Not Available': 'Not Available'
    }
    state_TX['derived_sex_desc'] = state_TX['derived_sex'].map(sex_mapping)

    # Remapper les valeurs de 'derived_ethnicity'
    ethnicity_mapping = {
        'Hispanic or Latino': 'Hispanic',
        'Not Hispanic or Latino': 'Not Hispanic',
        'Joint': 'Not Available',
        'Ethnicity Not Available': 'Not Available',
        'Free Form Text Only': 'Not Available'
    }
    state_TX['derived_ethnicity_desc'] = state_TX['derived_ethnicity'].map(ethnicity_mapping)

    return state_TX

def plot_sex_distribution(data, ax):
    """Plot loan distribution by sex."""
    filtered_data = data[data['action_taken_desc'].isin(['Loan originated', 'Application denied'])]
    sex_percentage = filtered_data.groupby(['derived_sex_desc', 'action_taken_desc']).size().unstack(fill_value=0)
    sex_percentage = sex_percentage.apply(lambda x: (x / x.sum()) * 100, axis=1)

    bars = ax.bar(sex_percentage.index, sex_percentage['Loan originated'], color='#FF9999', edgecolor='black', linewidth=1.5, label='Loan originated')
    ax.bar(sex_percentage.index, sex_percentage['Application denied'], bottom=sex_percentage['Loan originated'], color='#66B2FF', edgecolor='black', linewidth=1.5, label='Application denied')
    ax.set_title('Par Sexe', fontsize=14)
    ax.set_ylabel('Pourcentage (%)', fontsize=12)
    ax.legend(title='Action Taken', loc='upper right')
    ax.bar_label(bars)



def plot_ethnicity_distribution(data, ax):
  """Plot loan distribution by ethnicity."""
  ethnicity_percentage = data.groupby(['derived_ethnicity_desc', 'action_taken_desc']).size().unstack(fill_value=0)
  ethnicity_percentage = ethnicity_percentage.apply(lambda x: (x / x.sum()) * 100, axis=1)

  bars = ax.bar(ethnicity_percentage.index, ethnicity_percentage['Loan originated'], color='#FFB3E6', edgecolor='black', linewidth=1.5, label='Loan originated')
  ax.bar(ethnicity_percentage.index, ethnicity_percentage['Application denied'], bottom=ethnicity_percentage['Loan originated'], color='#B3B3FF', edgecolor='black', linewidth=1.5, label='Application denied')
  ax.set_title('Par Ethnicité', fontsize=14)
  ax.set_xlabel('Ethnicité', fontsize=12)
  ax.set_ylabel('Pourcentage (%)', fontsize=12)
  ax.legend(title='Action Taken', loc='upper right')
  ax.bar_label(bars)
  pass

# %%
df = rename_variables(df)
# Créer la figure et les axes
fig, axs = plt.subplots(1, 2, figsize=(18, 6))

# Plotting
plot_sex_distribution(df, axs[0])
plot_ethnicity_distribution(df, axs[1])

# Configuration de l'affichage
plt.tight_layout()
plt.suptitle('Analyse des Taux de Prêts Accordés et de Demandes Refusées', fontsize=20)
plt.subplots_adjust(top=0.85)  # Ajuster l'espace pour le titre
plt.show()

# %% [markdown]
# L'analyse des taux de prêts accordés révèle peu de différences selon le sexe, indiquant un traitement plus ou moins équitable. En revanche, des disparités significatives sont observées par ethnicité, suggérant des biais discriminatoires potentiels. Il reste à explorer d'autres variables pour déterminer si ces différences sont justifiées ou non.

# %% [markdown]
# ## Analyse du rate_spread

# %%
def analyze_rate_spread_by_race(df):
    # Convertir 'rate_spread' en numérique
    df['rate_spread'] = pd.to_numeric(df['rate_spread'], errors='coerce')

    # Vérifier les valeurs NaN après conversion
    print(f'Number of NaN values in rate_spread: {df["rate_spread"].isna().sum()}')

    # Supprimer les lignes avec NaN dans 'rate_spread'
    df = df.dropna(subset=['rate_spread'])

    # Grouper par 'derived_race' et calculer la moyenne et l'écart type
    rate_spread_by_race = df.groupby('derived_race')['rate_spread'].agg(['mean', 'std']).reset_index()

    # Calculer l'erreur standard
    rate_spread_by_race['error'] = rate_spread_by_race['std'] / np.sqrt(df.groupby('derived_race')['rate_spread'].count().values)

    # Créer le graphique à barres
    plt.figure(figsize=(12, 6))
    bars = sns.barplot(x='derived_race', y='mean', data=rate_spread_by_race, palette='muted', ci=None)

    # Ajouter des barres d'erreur
    plt.errorbar(x=rate_spread_by_race['derived_race'],
                 y=rate_spread_by_race['mean'],
                 yerr=rate_spread_by_race['error'],
                 fmt='none', c='black', capsize=5)

    # Définir les titres et les étiquettes
    plt.title('Taux Moyen de Rate Spread par Race', fontsize=16)
    plt.xlabel('Race', fontsize=12)
    plt.ylabel('Rate Spread (Moyenne)', fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Afficher le graphique
    plt.show()
    pass

# %%
analyze_rate_spread_by_race(df)
# Out:
# Number of NaN values in rate_spread: 956983
# C:\Users\asent\AppData\Local\Temp\ipykernel_16544\2340598318.py:19: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   bars = sns.barplot(x='derived_race', y='mean', data=rate_spread_by_race, palette='muted', ci=None)

# %% [markdown]
# Le rate spread, qui représente la différence entre le taux d'intérêt du prêt et le taux de référence, montre de grandes disparités entre les races, suggérant que certains groupes pourraient faire face à des conditions de crédit moins favorables.

# %% [markdown]
# ## Correlation des variables

# %%
def plot_corr_matrix(year):
    df = pd.read_csv('original_data/state_TX_'+str(year)+'.csv')
    dfcorr=df[["census_tract","loan_amount","interest_rate","rate_spread","total_loan_costs","total_points_and_fees","origination_charges","discount_points","lender_credits","loan_term","prepayment_penalty_term","intro_rate_period","property_value","multifamily_affordable_units","income","tract_population","tract_minority_population_percent","ffiec_msa_md_median_family_income","tract_to_msa_income_percentage","tract_owner_occupied_units","tract_one_to_four_family_homes","tract_median_age_of_housing_units"]]

    # change all string values in dfcorr to null value

    dfcorr = dfcorr.map(lambda x: None if isinstance(x, str) else x)

    corr_matrix = dfcorr.corr()

    corr_matrix = corr_matrix.round(2)

    plt.figure(figsize=(12, 10))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
    plt.title(f'Correlation Matrix of numerical data in {year}')
    plt.show()
    pass

# %%
plot_corr_matrix(year=2018)
# Out:
# C:\Users\asent\AppData\Local\Temp\ipykernel_16544\1361618804.py:2: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('original_data/state_TX_'+str(year)+'.csv')

# %% [markdown]
# Pour les variables numériques, on constate que la plupart d'entre elles ne présentent pas de corrélations importantes. Cependant, certaines variables sont fortement corrélées, comme le "interest rate" et le "rate spread". D'autres corrélations fortes sont observées entre "total_points_and_fees" et "lender_credits", car les charges dépendent fortement du crédit total, ainsi qu'entre "tract_population", "tract_owner_occupied_units" et "tract_one_to_four_family_homes", car ces variables représentent des aspects similaires, tels que le nombre de personnes dans le foyer.

# %%
dfcorr2=df[["derived_ethnicity","derived_race","derived_sex","purchaser_type","applicant_age","debt_to_income_ratio","applicant_ethnicity-1","applicant_ethnicity-2","applicant_ethnicity-3","co-applicant_ethnicity-1","co-applicant_ethnicity-2","applicant_ethnicity_observed","co-applicant_ethnicity_observed","applicant_race-1","applicant_race-2","applicant_race-3"]]

# Cramer's V correlation pour les variables catégorielles importants
def cramers_v(confusion_matrix):
    if confusion_matrix.size == 0:
        return np.nan
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    if n == 0:
        return np.nan
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k - 1) * (r - 1)) / (n - 1))
    rcorr = r - ((r - 1)**2) / (n - 1)
    kcorr = k - ((k - 1)**2) / (n - 1)
    return np.sqrt(phi2corr / min((kcorr - 1), (rcorr - 1)))

correlation_matrix = pd.DataFrame(index=dfcorr2.columns, columns=dfcorr2.columns)

for col1 in dfcorr2.columns:
    for col2 in dfcorr2.columns:
        contingency_table = pd.crosstab(dfcorr2[col1], dfcorr2[col2])
        if not contingency_table.empty:
            correlation_matrix.loc[col1, col2] = cramers_v(contingency_table)
        else:
            correlation_matrix.loc[col1, col2] = np.nan


correlation_matrix = correlation_matrix.astype(float)


plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',    vmin=-1, vmax=1,cbar_kws={'ticks': [-1,-0.75,-0.5,-0.25,0, 0.25, 0.5, 0.75, 1]})
plt.title('Correlation Matrix of Categorical Data (Cramer\'s V)')
plt.show()

# %% [markdown]
# Pour les variables catégorielles démographiques, la plupart d'entre elles sont corrélées, car elles sont souvent directement liées à la race.

# %% [markdown]
# ## **Problème de data science**

# %% [markdown]
# ![Data science project](Visualisations/focus_on_the_problem.png)

# %% [markdown]
# Le dataset HMDA contient plusieurs variables explicatives de la variable cible "action_taken," que nous cherchons à modéliser dans un premier temps selon deux classes : "application denied" (demande refusée) ou "loan originated" (prêt accordé). Après une étape de sélection des variables les plus pertinentes et une combinaison avec un deuxième jeu de données présentant les taux de richesse par zones, deux approches sont envisagées :
#
# * Classification supervisée : Nous utiliserons des algorithmes d'apprentissage supervisé basés sur les variables sélectionnées pour prédire la décision d'acceptation ou de refus de l'offre. Cette approche permettra de mieux comprendre les facteurs influençant la décision, et de détecter, après suppression des cas triviaux, la présence de biais discriminatoires potentiels dans les décisions de prêt.
#
# * Détection d'anomalies : En complément, une seconde approche consistera à examiner le motif de décision mentionné à travers la variable "denial-reason". En utilisant des techniques de détection d'anomalies, nous chercherons à relever des incohérences ou des irrégularités dans les décisions prises, ce qui pourrait révéler des cas suspects ou des biais non explicites.
#
# Ces deux approches nous permettront d'approfondir l'analyse des décisions et de mieux comprendre les dynamiques d'octroi de crédits tout en identifiant, si elles existent, des pratiques discriminatoires.
