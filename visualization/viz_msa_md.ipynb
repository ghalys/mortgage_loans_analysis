# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

year_example = 2020
path = '../original_data/'

# %%
df = pd.read_csv(path + 'state_TX_' + str(year_example)+'.csv')
df.head()
# Out:
# C:\Users\asent\AppData\Local\Temp\ipykernel_12740\3744720646.py:1: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path + 'state_TX_' + str(year_example)+'.csv')
#    activity_year                   lei  derived_msa-md state_code  \
# 0           2020  549300RBX56T2MW5HO19           19124         TX
# 1           2020  549300RBX56T2MW5HO19           26420         TX
# 2           2020  549300RBX56T2MW5HO19           26420         TX
# 3           2020  549300RBX56T2MW5HO19           26420         TX
# 4           2020  549300RBX56T2MW5HO19           19124         TX
#
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0      48121.0  4.812102e+10                     C   Conventional:First Lien
# 1      48339.0  4.833969e+10                     C   Conventional:First Lien
# ...

# %%
# distribution of data by action_taken
df['action_taken'].value_counts()
# Out:
# action_taken
# 1    1010721
# 6     276212
# 4     270779
# 3     242833
# 5     109929
# 2      56092
# 8        852
# 7        708
# Name: count, dtype: int64

# %%
df_denied = df[df['action_taken'] == 2]

df_denied['loan_to_value_ratio'].value_counts(dropna=False)
# Out:
# loan_to_value_ratio
# NaN       10238
# Exempt     2343
# 80.0       2302
# 80.0       1974
# 95.0       1157
#           ...
# 34.278        1
# 82.591        1
# 52.925        1
# 75.054        1
# 78.135        1
# Name: count, Length: 21633, dtype: int64
